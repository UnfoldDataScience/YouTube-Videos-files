# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

# convert into dataset matrix
def convertToMatrix(data, step):
 X, Y =[], []
 for i in range(len(data)-step):
  d=i+step  
  X.append(data[i:d,])
  Y.append(data[d,])
 return np.array(X), np.array(Y)

step = 4
N = 1000    
Tp = 800    

t=np.arange(0,N)
x=np.sin(0.02*t)+2*np.random.rand(N)
df = pd.DataFrame(x)
df.head()

plt.plot(df)
plt.show()

values=df.values
train,test = values[0:Tp,:], values[Tp:N,:]

# add step elements into train and test
test = np.append(test,np.repeat(test[-1,],step))
train = np.append(train,np.repeat(train[-1,],step))
 
trainX,trainY =convertToMatrix(train,step)
testX,testY =convertToMatrix(test,step)
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

model = Sequential()
model.add(SimpleRNN(units=32, input_shape=(1,step), activation="relu"))
model.add(Dense(8, activation="relu")) 
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='rmsprop')
model.summary()

model.fit(trainX,trainY, epochs=100, batch_size=16, verbose=2)
trainPredict = model.predict(trainX)
testPredict= model.predict(testX)
predicted=np.concatenate((trainPredict,testPredict),axis=0)

trainScore = model.evaluate(trainX, trainY, verbose=0)
print(trainScore)

index = df.index.values
plt.plot(index,df)
plt.plot(index,predicted)
plt.axvline(df.index[Tp], c="r")
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 32)                1184
#
#  dense (Dense)               (None, 8)                 264
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,457
# Trainable params: 1,457
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 50/50 - 2s - loss: 1.7183 - 2s/epoch - 42ms/step
# Epoch 2/100
# 50/50 - 0s - loss: 0.5870 - 109ms/epoch - 2ms/step
# Epoch 3/100
# 50/50 - 0s - loss: 0.4124 - 121ms/epoch - 2ms/step
# Epoch 4/100
# 50/50 - 0s - loss: 0.4045 - 122ms/epoch - 2ms/step
# Epoch 5/100
# 50/50 - 0s - loss: 0.4009 - 121ms/epoch - 2ms/step
# Epoch 6/100
# 50/50 - 0s - loss: 0.3956 - 124ms/epoch - 2ms/step
# Epoch 7/100
# 50/50 - 0s - loss: 0.3946 - 150ms/epoch - 3ms/step
# Epoch 8/100
# 50/50 - 0s - loss: 0.3933 - 146ms/epoch - 3ms/step
# Epoch 9/100
# 50/50 - 0s - loss: 0.3917 - 126ms/epoch - 3ms/step
# Epoch 10/100
# 50/50 - 0s - loss: 0.3915 - 128ms/epoch - 3ms/step
# Epoch 11/100
# 50/50 - 0s - loss: 0.3900 - 134ms/epoch - 3ms/step
# Epoch 12/100
# 50/50 - 0s - loss: 0.3905 - 128ms/epoch - 3ms/step
# Epoch 13/100
# 50/50 - 0s - loss: 0.3880 - 133ms/epoch - 3ms/step
# Epoch 14/100
# 50/50 - 0s - loss: 0.3880 - 133ms/epoch - 3ms/step
# Epoch 15/100
# 50/50 - 0s - loss: 0.3878 - 135ms/epoch - 3ms/step
# Epoch 16/100
# 50/50 - 0s - loss: 0.3864 - 110ms/epoch - 2ms/step
# Epoch 17/100
# 50/50 - 0s - loss: 0.3883 - 130ms/epoch - 3ms/step
# Epoch 18/100
# 50/50 - 0s - loss: 0.3864 - 108ms/epoch - 2ms/step
# Epoch 19/100
# 50/50 - 0s - loss: 0.3846 - 112ms/epoch - 2ms/step
# Epoch 20/100
# 50/50 - 0s - loss: 0.3848 - 121ms/epoch - 2ms/step
# Epoch 21/100
# 50/50 - 0s - loss: 0.3833 - 141ms/epoch - 3ms/step
# Epoch 22/100
# 50/50 - 0s - loss: 0.3831 - 133ms/epoch - 3ms/step
# Epoch 23/100
# 50/50 - 0s - loss: 0.3827 - 134ms/epoch - 3ms/step
# Epoch 24/100
# 50/50 - 0s - loss: 0.3839 - 128ms/epoch - 3ms/step
# Epoch 25/100
# 50/50 - 0s - loss: 0.3827 - 135ms/epoch - 3ms/step
# Epoch 26/100
# 50/50 - 0s - loss: 0.3798 - 132ms/epoch - 3ms/step
# Epoch 27/100
# 50/50 - 0s - loss: 0.3823 - 128ms/epoch - 3ms/step
# Epoch 28/100
# 50/50 - 0s - loss: 0.3819 - 112ms/epoch - 2ms/step
# Epoch 29/100
# 50/50 - 0s - loss: 0.3819 - 127ms/epoch - 3ms/step
# Epoch 30/100
# 50/50 - 0s - loss: 0.3811 - 138ms/epoch - 3ms/step
# Epoch 31/100
# 50/50 - 0s - loss: 0.3820 - 146ms/epoch - 3ms/step
# Epoch 32/100
# 50/50 - 0s - loss: 0.3783 - 135ms/epoch - 3ms/step
# Epoch 33/100
# 50/50 - 0s - loss: 0.3804 - 134ms/epoch - 3ms/step
# Epoch 34/100
# 50/50 - 0s - loss: 0.3791 - 129ms/epoch - 3ms/step
# Epoch 35/100
# 50/50 - 0s - loss: 0.3801 - 118ms/epoch - 2ms/step
# Epoch 36/100
# 50/50 - 0s - loss: 0.3807 - 125ms/epoch - 3ms/step
# Epoch 37/100
# 50/50 - 0s - loss: 0.3788 - 127ms/epoch - 3ms/step
# Epoch 38/100
# 50/50 - 0s - loss: 0.3779 - 125ms/epoch - 2ms/step
# Epoch 39/100
# 50/50 - 0s - loss: 0.3773 - 129ms/epoch - 3ms/step
# Epoch 40/100
# 50/50 - 0s - loss: 0.3779 - 114ms/epoch - 2ms/step
# Epoch 41/100
# 50/50 - 0s - loss: 0.3775 - 111ms/epoch - 2ms/step
# Epoch 42/100
# 50/50 - 0s - loss: 0.3757 - 114ms/epoch - 2ms/step
# Epoch 43/100
# 50/50 - 0s - loss: 0.3760 - 102ms/epoch - 2ms/step
# Epoch 44/100
# 50/50 - 0s - loss: 0.3755 - 120ms/epoch - 2ms/step
# Epoch 45/100
# 50/50 - 0s - loss: 0.3777 - 113ms/epoch - 2ms/step
# Epoch 46/100
# 50/50 - 0s - loss: 0.3773 - 127ms/epoch - 3ms/step
# Epoch 47/100
# 50/50 - 0s - loss: 0.3770 - 120ms/epoch - 2ms/step
# Epoch 48/100
# 50/50 - 0s - loss: 0.3750 - 116ms/epoch - 2ms/step
# Epoch 49/100
# 50/50 - 0s - loss: 0.3727 - 111ms/epoch - 2ms/step
# Epoch 50/100
# 50/50 - 0s - loss: 0.3744 - 127ms/epoch - 3ms/step
# Epoch 51/100
# 50/50 - 0s - loss: 0.3741 - 135ms/epoch - 3ms/step
# Epoch 52/100
# 50/50 - 0s - loss: 0.3741 - 116ms/epoch - 2ms/step
# Epoch 53/100
# 50/50 - 0s - loss: 0.3732 - 137ms/epoch - 3ms/step
# Epoch 54/100
# 50/50 - 0s - loss: 0.3731 - 127ms/epoch - 3ms/step
# Epoch 55/100
# 50/50 - 0s - loss: 0.3730 - 127ms/epoch - 3ms/step
# Epoch 56/100
# 50/50 - 0s - loss: 0.3715 - 121ms/epoch - 2ms/step
# Epoch 57/100
# 50/50 - 0s - loss: 0.3697 - 129ms/epoch - 3ms/step
# Epoch 58/100
# 50/50 - 0s - loss: 0.3732 - 129ms/epoch - 3ms/step
# Epoch 59/100
# 50/50 - 0s - loss: 0.3720 - 124ms/epoch - 2ms/step
# Epoch 60/100
# 50/50 - 0s - loss: 0.3707 - 125ms/epoch - 3ms/step
# Epoch 61/100
# 50/50 - 0s - loss: 0.3706 - 126ms/epoch - 3ms/step
# Epoch 62/100
# 50/50 - 0s - loss: 0.3714 - 122ms/epoch - 2ms/step
# Epoch 63/100
# 50/50 - 0s - loss: 0.3711 - 114ms/epoch - 2ms/step
# Epoch 64/100
# 50/50 - 0s - loss: 0.3705 - 118ms/epoch - 2ms/step
# Epoch 65/100
# 50/50 - 0s - loss: 0.3689 - 129ms/epoch - 3ms/step
# Epoch 66/100
# 50/50 - 0s - loss: 0.3685 - 121ms/epoch - 2ms/step
# Epoch 67/100
# 50/50 - 0s - loss: 0.3707 - 127ms/epoch - 3ms/step
# Epoch 68/100
# 50/50 - 0s - loss: 0.3705 - 126ms/epoch - 3ms/step
# Epoch 69/100
# 50/50 - 0s - loss: 0.3685 - 136ms/epoch - 3ms/step
# Epoch 70/100
# 50/50 - 0s - loss: 0.3686 - 129ms/epoch - 3ms/step
# Epoch 71/100
# 50/50 - 0s - loss: 0.3678 - 122ms/epoch - 2ms/step
# Epoch 72/100
# 50/50 - 0s - loss: 0.3705 - 137ms/epoch - 3ms/step
# Epoch 73/100
# 50/50 - 0s - loss: 0.3681 - 138ms/epoch - 3ms/step
# Epoch 74/100
# 50/50 - 0s - loss: 0.3669 - 142ms/epoch - 3ms/step
# Epoch 75/100
# 50/50 - 0s - loss: 0.3677 - 137ms/epoch - 3ms/step
# Epoch 76/100
# 50/50 - 0s - loss: 0.3678 - 134ms/epoch - 3ms/step
# Epoch 77/100
# 50/50 - 0s - loss: 0.3671 - 121ms/epoch - 2ms/step
# Epoch 78/100
# 50/50 - 0s - loss: 0.3630 - 122ms/epoch - 2ms/step
# Epoch 79/100
# 50/50 - 0s - loss: 0.3680 - 109ms/epoch - 2ms/step
# Epoch 80/100
# 50/50 - 0s - loss: 0.3668 - 107ms/epoch - 2ms/step
# Epoch 81/100
# 50/50 - 0s - loss: 0.3645 - 113ms/epoch - 2ms/step
# Epoch 82/100
# 50/50 - 0s - loss: 0.3649 - 123ms/epoch - 2ms/step
# Epoch 83/100
# 50/50 - 0s - loss: 0.3644 - 120ms/epoch - 2ms/step
# Epoch 84/100
# 50/50 - 0s - loss: 0.3659 - 132ms/epoch - 3ms/step
# Epoch 85/100
# 50/50 - 0s - loss: 0.3637 - 120ms/epoch - 2ms/step
# Epoch 86/100
# 50/50 - 0s - loss: 0.3672 - 130ms/epoch - 3ms/step
# Epoch 87/100
# 50/50 - 0s - loss: 0.3635 - 127ms/epoch - 3ms/step
# Epoch 88/100
# 50/50 - 0s - loss: 0.3638 - 130ms/epoch - 3ms/step
# Epoch 89/100
# 50/50 - 0s - loss: 0.3628 - 124ms/epoch - 2ms/step
# Epoch 90/100
# 50/50 - 0s - loss: 0.3634 - 147ms/epoch - 3ms/step
# Epoch 91/100
# 50/50 - 0s - loss: 0.3643 - 123ms/epoch - 2ms/step
# Epoch 92/100
# 50/50 - 0s - loss: 0.3647 - 128ms/epoch - 3ms/step
# Epoch 93/100
# 50/50 - 0s - loss: 0.3623 - 134ms/epoch - 3ms/step
# Epoch 94/100
# 50/50 - 0s - loss: 0.3643 - 135ms/epoch - 3ms/step
# Epoch 95/100
# 50/50 - 0s - loss: 0.3640 - 132ms/epoch - 3ms/step
# Epoch 96/100
# 50/50 - 0s - loss: 0.3608 - 137ms/epoch - 3ms/step
# Epoch 97/100
# 50/50 - 0s - loss: 0.3652 - 127ms/epoch - 3ms/step
# Epoch 98/100
# 50/50 - 0s - loss: 0.3652 - 125ms/epoch - 3ms/step
# Epoch 99/100
# 50/50 - 0s - loss: 0.3628 - 136ms/epoch - 3ms/step
# Epoch 100/100
# 50/50 - 0s - loss: 0.3613 - 140ms/epoch - 3ms/step
# 25/25 [==============================] - 1s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 0.3564453125
